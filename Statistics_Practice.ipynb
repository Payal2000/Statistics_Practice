# %% [markdown]
# <a href="https://colab.research.google.com/github/Payal2000/Statistics_Practice/blob/main/Statistics_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
file_url = "https://raw.githubusercontent.com/Payal2000/Statistics_Practice/refs/heads/main/Income.csv"
data = pd.read_csv(file_url)

# %%
file1_url = "https://raw.githubusercontent.com/codebasics/math-for-machine-learning/refs/heads/main/3_normal_distribution/heights.csv"
data1 = pd.read_csv(file1_url)

# %%
data.head(10)
# Out:
#         Name    Income
# 0        Rob      5000
# 1      Rafiq      6000
# 2       Nina      4000
# 3      Sofia      7500
# 4      Mohan      8000
# 5        Tao      7000
# 6  Elon Musk  10000000

# %%
data.describe()
# Out:
#              Income
# count  7.000000e+00
# mean   1.433929e+06
# std    3.777283e+06
# min    4.000000e+03
# 25%    5.500000e+03
# 50%    7.000000e+03
# 75%    7.750000e+03
# max    1.000000e+07

# %% [markdown]
# ## **Looking for Quantiles**

# %%
data.Income.quantile(0)
# Out:
# 4000.0

# %%
data.Income.quantile(0.75)
# Out:
# 7750.0

# %%
data.Income.quantile(0.90)
# Out:
# 4004800.0000000037

# %%
data.Income.quantile(1)
# Out:
# 10000000.0

# %% [markdown]
# ## **Outlier Detection**

# %%
percentile_99 = data.Income.quantile(0.99)
percentile_99
# Out:
# 9400479.999999994

# %%
data_outlier = data[data.Income > percentile_99]
data_outlier
# Out:
#         Name    Income
# 6  Elon Musk  10000000

# %% [markdown]
# ## **Data without outlier**

# %%
data_no_outlier = data[data.Income < percentile_99]
data_no_outlier
# Out:
#     Name  Income
# 0    Rob    5000
# 1  Rafiq    6000
# 2   Nina    4000
# 3  Sofia    7500
# 4  Mohan    8000
# 5    Tao    7000

# %% [markdown]
# ## **Trying Standard Deviation**

# %%
data1.head(10)
# Out:
#   gender     height
# 0   Male  73.847017
# 1   Male  68.781904
# 2   Male  74.110105
# 3   Male  71.730978
# 4   Male  69.881796
# 5   Male  67.253016
# 6   Male  68.785081
# 7   Male  68.348516
# 8   Male  67.018950
# 9   Male  63.456494

# %%
data1.shape
# Out:
# (10000, 2)

# %%
data1.height.describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: height, dtype: float64

# %% [markdown]
# ## **Histogram**

# %%
sn.histplot(data1.height, kde = True)
# Out:
# <Axes: xlabel='height', ylabel='Count'>

# %% [markdown]
# ## Storing mean in new varibale

# %%
mean = data1.height.mean()
mean
# Out:
# 66.367559754866

# %%
std_deviation = data1.height.std()
std_deviation
# Out:
# 3.847528120795573

# %% [markdown]
# ## Outlier Removal
#
# 3 standard deviation method from left and right

# %%
mean - 3*std_deviation
# Out:
# 54.824975392479274

# %%
mean + 3*std_deviation
# Out:
# 77.91014411725271

# %%
data1[(data1.height < 54.824) | (data1.height > 77.910)]
# Out:
#       gender     height
# 994     Male  78.095867
# 1317    Male  78.462053
# 2014    Male  78.998742
# 3285    Male  78.528210
# 3757    Male  78.621374
# 6624  Female  54.616858
# 9285  Female  54.263133

# %%
data1_no_outlier = data1[(data1.height > 54.824) & (data1.height < 77.910)]
data1_no_outlier
# Out:
#       gender     height
# 0       Male  73.847017
# 1       Male  68.781904
# 2       Male  74.110105
# 3       Male  71.730978
# 4       Male  69.881796
# ...      ...        ...
# 9995  Female  66.172652
# 9996  Female  67.067155
# 9997  Female  63.867992
# 9998  Female  69.034243
# 9999  Female  61.944246
#
# [9993 rows x 2 columns]

# %%
data1_no_outlier.shape
# Out:
# (9993, 2)

# %%
sn.histplot(data1_no_outlier, kde = True)
# Out:
# <Axes: ylabel='Count'>
